# %%
import pandas as pd
import numpy as np

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Default Prediction/default-prediction/data/train.csv')
test_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Default Prediction/default-prediction/data/test.csv')
df.head()
# Out:
#    int_rate  annual_inc    dti  ...  fico_range_low  fico_range_high  depvar
# 0    0.0824     21000.0  29.19  ...             765              769       0
# 1    0.1299     80000.0   4.82  ...             665              669       0
# 2    0.1299     38000.0  23.66  ...             670              674       0
# 3    0.1367    100000.0  16.27  ...             680              684       1
# 4    0.1269     30000.0  25.28  ...             660              664       1
#
# [5 rows x 76 columns]

# %%
test_df
# Out:
#        int_rate  annual_inc    dti  ...  fico_range_low  fico_range_high     ID
# 0        0.1449     16380.0  26.08  ...             700              704      0
# 1        0.1899     65000.0  13.97  ...             675              679      1
# 2        0.1049     53000.0  23.28  ...             675              679      2
# 3        0.1757     71800.0  30.32  ...             665              669      3
# 4        0.2020     50000.0  25.61  ...             710              714      4
# ...         ...         ...    ...  ...             ...              ...    ...
# 35811    0.1049    110000.0   9.02  ...             665              669  35811
# 35812    0.0824     45000.0  32.56  ...             705              709  35812
# 35813    0.1368     49000.0  17.60  ...             705              709  35813
# 35814    0.1139     84852.0   9.96  ...             725              729  35814
# 35815    0.1274     60000.0   3.64  ...             675              679  35815
#
# ...

# %% [markdown]
# 연속적인 값은 하나의 feature로 만들어준다.
#
# emp_length1 ~ 12
#
# mths_since_last_delinq1 ~ 11 : 마지막 체납이 지금으로부터 몇개월 전에 었는지를 나타내는 변수 (Months since the last delinquency)

# %%
df.columns
# Out:
# Index(['int_rate', 'annual_inc', 'dti', 'delinq_2yrs', 'inq_last_6mths',
#        'pub_rec', 'revol_bal', 'total_acc', 'collections_12_mths_ex_med',
#        'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal',
#        'chargeoff_within_12_mths', 'delinq_amnt', 'tax_liens', 'emp_length1',
#        'emp_length2', 'emp_length3', 'emp_length4', 'emp_length5',
#        'emp_length6', 'emp_length7', 'emp_length8', 'emp_length9',
#        'emp_length10', 'emp_length11', 'emp_length12', 'home_ownership1',
#        'home_ownership2', 'home_ownership3', 'home_ownership4',
#        'home_ownership5', 'home_ownership6', 'verification_status1',
#        'verification_status2', 'verification_status3', 'purpose1', 'purpose2',
#        'purpose3', 'purpose4', 'purpose5', 'purpose6', 'purpose7', 'purpose8',
#        'purpose9', 'purpose10', 'purpose11', 'purpose12', 'purpose13',
#        'purpose14', 'initial_list_status1', 'initial_list_status2',
# ...

# %%
# 해당값이 하나의 기간만 나타내는 지 확인
df[['emp_length1',
       'emp_length2', 'emp_length3', 'emp_length4', 'emp_length5',
       'emp_length6', 'emp_length7', 'emp_length8', 'emp_length9',
       'emp_length10', 'emp_length11', 'emp_length12']].sum(axis=1).sum()
# Out:
# 100000

# %%
emp_length = df[['emp_length1',
       'emp_length2', 'emp_length3', 'emp_length4', 'emp_length5',
       'emp_length6', 'emp_length7', 'emp_length8', 'emp_length9',
       'emp_length10', 'emp_length11', 'emp_length12']].to_numpy().dot(np.arange(1, 13))

# %%
test_emp_length = test_df[['emp_length1',
       'emp_length2', 'emp_length3', 'emp_length4', 'emp_length5',
       'emp_length6', 'emp_length7', 'emp_length8', 'emp_length9',
       'emp_length10', 'emp_length11', 'emp_length12']].to_numpy().dot(np.arange(1, 13))

# %%
emp_length
# Out:
# array([ 1,  2,  4, ...,  4, 12,  5])

# %%
emp_length.max()
# Out:
# 12

# %%
# 해당값이 하나의 기간만 나타내는 지 확인
df[['mths_since_last_delinq1', 'mths_since_last_delinq2',
       'mths_since_last_delinq3', 'mths_since_last_delinq4',
       'mths_since_last_delinq5', 'mths_since_last_delinq6',
       'mths_since_last_delinq7', 'mths_since_last_delinq8',
       'mths_since_last_delinq9', 'mths_since_last_delinq10',
       'mths_since_last_delinq11']].sum(axis=1)
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 99995    1
# 99996    1
# 99997    1
# 99998    1
# 99999    1
# Length: 100000, dtype: int64

# %%
df[['mths_since_last_delinq1', 'mths_since_last_delinq2',
       'mths_since_last_delinq3', 'mths_since_last_delinq4',
       'mths_since_last_delinq5', 'mths_since_last_delinq6',
       'mths_since_last_delinq7', 'mths_since_last_delinq8',
       'mths_since_last_delinq9', 'mths_since_last_delinq10',
       'mths_since_last_delinq11']].sum(axis=1).sum()
# Out:
# 100000

# %%
mths_since_last_delinq = df[['mths_since_last_delinq1', 'mths_since_last_delinq2',
       'mths_since_last_delinq3', 'mths_since_last_delinq4',
       'mths_since_last_delinq5', 'mths_since_last_delinq6',
       'mths_since_last_delinq7', 'mths_since_last_delinq8',
       'mths_since_last_delinq9', 'mths_since_last_delinq10',
       'mths_since_last_delinq11']].to_numpy().dot(np.arange(1, 12))

# %%
test_mths_since_last_delinq = test_df[['mths_since_last_delinq1', 'mths_since_last_delinq2',
       'mths_since_last_delinq3', 'mths_since_last_delinq4',
       'mths_since_last_delinq5', 'mths_since_last_delinq6',
       'mths_since_last_delinq7', 'mths_since_last_delinq8',
       'mths_since_last_delinq9', 'mths_since_last_delinq10',
       'mths_since_last_delinq11']].to_numpy().dot(np.arange(1, 12))

# %%
mths_since_last_delinq.max()
# Out:
# 11

# %%
df2 = df.drop(['mths_since_last_delinq1', 'mths_since_last_delinq2',
       'mths_since_last_delinq3', 'mths_since_last_delinq4',
       'mths_since_last_delinq5', 'mths_since_last_delinq6',
       'mths_since_last_delinq7', 'mths_since_last_delinq8',
       'mths_since_last_delinq9', 'mths_since_last_delinq10',
       'mths_since_last_delinq11',
       'emp_length1',
       'emp_length2', 'emp_length3', 'emp_length4', 'emp_length5',
       'emp_length6', 'emp_length7', 'emp_length8', 'emp_length9',
       'emp_length10', 'emp_length11', 'emp_length12'], axis=1)

# %%
test_df2 = test_df.drop(['mths_since_last_delinq1', 'mths_since_last_delinq2',
       'mths_since_last_delinq3', 'mths_since_last_delinq4',
       'mths_since_last_delinq5', 'mths_since_last_delinq6',
       'mths_since_last_delinq7', 'mths_since_last_delinq8',
       'mths_since_last_delinq9', 'mths_since_last_delinq10',
       'mths_since_last_delinq11',
       'emp_length1',
       'emp_length2', 'emp_length3', 'emp_length4', 'emp_length5',
       'emp_length6', 'emp_length7', 'emp_length8', 'emp_length9',
       'emp_length10', 'emp_length11', 'emp_length12'], axis=1)

# %%
df2['mths_since_last_delinq'] = mths_since_last_delinq

# %%
test_df2['mths_since_last_delinq'] = test_mths_since_last_delinq

# %%
test_df2['emp_length'] = test_emp_length

# %%
df2
# Out:
#        int_rate  annual_inc    dti  ...  depvar  mths_since_last_delinq  emp_length
# 0        0.0824     21000.0  29.19  ...       0                       1           1
# 1        0.1299     80000.0   4.82  ...       0                       1           2
# 2        0.1299     38000.0  23.66  ...       0                      11           4
# 3        0.1367    100000.0  16.27  ...       1                       5           3
# 4        0.1269     30000.0  25.28  ...       1                       1           4
# ...         ...         ...    ...  ...     ...                     ...         ...
# 99995    0.1757     65000.0  17.67  ...       1                       1           7
# 99996    0.0890     65000.0   2.88  ...       0                       1          11
# 99997    0.1349     46000.0  32.12  ...       0                       1           4
# 99998    0.2115     31000.0   4.53  ...       1                       1          12
# ...

# %% [markdown]
# 데이터 정규화 하기
# 원핫 인코딩과 'depvar' 은 제외한다.
#
# *   항목 추가
# *   항목 추가

# %%
df2.columns
# Out:
# Index(['int_rate', 'annual_inc', 'dti', 'delinq_2yrs', 'inq_last_6mths',
#        'pub_rec', 'revol_bal', 'total_acc', 'collections_12_mths_ex_med',
#        'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal',
#        'chargeoff_within_12_mths', 'delinq_amnt', 'tax_liens',
#        'home_ownership1', 'home_ownership2', 'home_ownership3',
#        'home_ownership4', 'home_ownership5', 'home_ownership6',
#        'verification_status1', 'verification_status2', 'verification_status3',
#        'purpose1', 'purpose2', 'purpose3', 'purpose4', 'purpose5', 'purpose6',
#        'purpose7', 'purpose8', 'purpose9', 'purpose10', 'purpose11',
#        'purpose12', 'purpose13', 'purpose14', 'initial_list_status1',
#        'initial_list_status2', 'funded_amnt', 'funded_amnt_inv',
#        'total_rec_late_fee', 'term1', 'open_acc', 'installment', 'revol_util',
#        'out_prncp', 'out_prncp_inv', 'total_rec_int', 'fico_range_low',
# ...

# %%
df3 = df2.drop(['home_ownership1', 'home_ownership2', 'home_ownership3', 'home_ownership4', 'home_ownership5', 'home_ownership6', 'depvar', 'verification_status1', 'verification_status2', 'verification_status3', 'purpose1', 'purpose2', 'purpose3', 'purpose4', 'purpose5', 'purpose6', 'purpose7', 'purpose8', 'purpose9', 'purpose10', 'purpose11', 'purpose12', 'purpose13', 'purpose14', 'initial_list_status1', 'initial_list_status2'], axis=1)
normalization_df = (df3 - df3.mean())/df3.std()
normalization_df.head()
# Out:
#    int_rate  annual_inc  ...  mths_since_last_delinq  emp_length
# 0 -1.081754   -0.714580  ...               -0.813329   -1.144282
# 1 -0.020849    0.075520  ...               -0.813329   -0.864096
# 2 -0.020849   -0.486924  ...                2.118602   -0.303724
# 3  0.131028    0.343351  ...                0.359443   -0.583910
# 4 -0.087854   -0.594056  ...               -0.813329   -0.303724
#
# [5 rows x 29 columns]

# %%
test_df3 = test_df2.drop(['home_ownership1', 'home_ownership2', 'home_ownership3', 'home_ownership4', 'home_ownership5', 'home_ownership6', 'verification_status1', 'verification_status2', 'verification_status3', 'purpose1', 'purpose2', 'purpose3', 'purpose4', 'purpose5', 'purpose6', 'purpose7', 'purpose8', 'purpose9', 'purpose10', 'purpose11', 'purpose12', 'purpose13', 'purpose14', 'initial_list_status1', 'initial_list_status2'], axis=1)
test_normalization_df = (test_df3 - df3.mean())/df3.std()

# %%
normalization_df.max()
# Out:
# int_rate                        3.999422
# annual_inc                    110.153863
# dti                             3.734139
# delinq_2yrs                    21.719490
# inq_last_6mths                  5.599655
# pub_rec                        94.886285
# revol_bal                      44.304520
# total_acc                      12.733609
# collections_12_mths_ex_med     33.137015
# acc_now_delinq                 71.713939
# tot_coll_amt                   96.689459
# tot_cur_bal                    20.180748
# chargeoff_within_12_mths       63.503216
# delinq_amnt                   105.788928
# tax_liens                     134.471282
# funded_amnt                     3.102803
# funded_amnt_inv                 3.104657
# total_rec_late_fee             58.524558
# term1                           0.410283
# open_acc                       12.892878
# installment                     4.327673
# revol_util                     35.032207
# out_prncp                     129.102045
# ...

# %% [markdown]
# 전처리 된 데이터 저장

# %%
preprocessed_df = normalization_df
columns = ['home_ownership1', 'home_ownership2', 'home_ownership3', 'home_ownership4', 'home_ownership5', 'home_ownership6', 'verification_status1', 'verification_status2', 'verification_status3', 'purpose1', 'purpose2', 'purpose3', 'purpose4', 'purpose5', 'purpose6', 'purpose7', 'purpose8', 'purpose9', 'purpose10', 'purpose11', 'purpose12', 'purpose13', 'purpose14', 'initial_list_status1', 'initial_list_status2', 'depvar']
for col in columns:
    preprocessed_df[col] = df2[col]

# %%
preprocessed_df
# Out:
#        int_rate  annual_inc  ...  initial_list_status2  depvar
# 0     -1.081754   -0.714580  ...                     1       0
# 1     -0.020849    0.075520  ...                     1       0
# 2     -0.020849   -0.486924  ...                     1       0
# 3      0.131028    0.343351  ...                     1       1
# 4     -0.087854   -0.594056  ...                     1       1
# ...         ...         ...  ...                   ...     ...
# 99995  1.002087   -0.125353  ...                     1       1
# 99996 -0.934344   -0.125353  ...                     0       0
# 99997  0.090825   -0.379792  ...                     1       0
# 99998  1.801674   -0.580665  ...                     1       1
# 99999  0.649196    0.678139  ...                     1       0
#
# [100000 rows x 55 columns]

# %%
test_preprocessed_df = test_normalization_df
columns = ['home_ownership1', 'home_ownership2', 'home_ownership3', 'home_ownership4', 'home_ownership5', 'home_ownership6', 'verification_status1', 'verification_status2', 'verification_status3', 'purpose1', 'purpose2', 'purpose3', 'purpose4', 'purpose5', 'purpose6', 'purpose7', 'purpose8', 'purpose9', 'purpose10', 'purpose11', 'purpose12', 'purpose13', 'purpose14', 'initial_list_status1', 'initial_list_status2']
for col in columns:
    test_preprocessed_df[col] = test_df2[col]

# %%
test_preprocessed_df
# Out:
#        ID  acc_now_delinq  ...  initial_list_status1  initial_list_status2
# 0     NaN       -0.069391  ...                     0                     1
# 1     NaN       -0.069391  ...                     0                     1
# 2     NaN       -0.069391  ...                     0                     1
# 3     NaN       -0.069391  ...                     0                     1
# 4     NaN       -0.069391  ...                     1                     0
# ...    ..             ...  ...                   ...                   ...
# 35811 NaN       -0.069391  ...                     0                     1
# 35812 NaN       -0.069391  ...                     0                     1
# 35813 NaN       -0.069391  ...                     1                     0
# 35814 NaN       -0.069391  ...                     0                     1
# 35815 NaN       -0.069391  ...                     0                     1
#
# [35816 rows x 55 columns]

# %%
preprocessed_df.to_csv('/content/drive/MyDrive/Colab Notebooks/Default Prediction/default-prediction/data/preprocessed_train.csv', index=False)
test_preprocessed_df.to_csv('/content/drive/MyDrive/Colab Notebooks/Default Prediction/default-prediction/data/preprocessed_test.csv', index=False)

# %%
tem = submit = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Default Prediction/default-prediction/data/preprocessed_train.csv')

# %%
tem
# Out:
#        int_rate  annual_inc  ...  initial_list_status2  depvar
# 0     -1.081754   -0.714580  ...                     1       0
# 1     -0.020849    0.075520  ...                     1       0
# 2     -0.020849   -0.486924  ...                     1       0
# 3      0.131028    0.343351  ...                     1       1
# 4     -0.087854   -0.594056  ...                     1       1
# ...         ...         ...  ...                   ...     ...
# 99995  1.002087   -0.125353  ...                     1       1
# 99996 -0.934344   -0.125353  ...                     0       0
# 99997  0.090825   -0.379792  ...                     1       0
# 99998  1.801674   -0.580665  ...                     1       1
# 99999  0.649196    0.678139  ...                     1       0
#
# [100000 rows x 55 columns]
